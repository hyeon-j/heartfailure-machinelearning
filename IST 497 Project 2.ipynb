# %%
# Pandas
import pandas as pd

# Sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix

# %%
# Putting data into DataFrame
df = pd.read_csv('heart.csv', sep=',')

# Convert categorical values into numerical categorical values (Sex, ChestPainType, RestingECG, ExerciseAngina, St_Slope)
df['Sex'] = pd.factorize(df['Sex'])[0]
df['ChestPainType'] = pd.factorize(df['ChestPainType'])[0]
df['RestingECG'] = pd.factorize(df['RestingECG'])[0]
df['ExerciseAngina'] = pd.factorize(df['ExerciseAngina'])[0]
df['ST_Slope'] = pd.factorize(df['ST_Slope'])[0]

# Normalized Data
df_norm = pd.DataFrame(preprocessing.normalize(df), columns = df.columns)
df_norm["HeartDisease"] = df["HeartDisease"]

# %%
# Function to run model and display information

def run_model(model, data, norm):
    
    X_train, X_test, y_train, y_test = train_test_split(data.drop("HeartDisease", 1), data.HeartDisease, test_size = 0.2)
    X_train = X_train.astype('float')
    X_test = X_test.astype('float')
    y_train = y_train.astype('float')
    y_test = y_test.astype('float')
    
    print("- Model: ", model, "\n")
    
    if norm == True:
        print("- Data: Normalized", "\n")
    else:
        print("- Data: Not normalized", "\n")
    
    model.fit(X_train, y_train)
    score = model.score(X_test, y_test)
    print("- Accuracy score: ", score, "\n")

    predictions = model.predict(X_test)
    print("- Classification Report: \n\n", classification_report(y_test, predictions))

    matrix = confusion_matrix(y_test, predictions)
    print("- Confusion Matrix: \n")
    print("\tTrue Positive: ", matrix[1][0], "\tTrue Negative: ", matrix[0][0])
    print("\tFalse Positive: ", matrix[0][1], "\tFalse Negative: ", matrix[1][0])
    
    print("\n-------------------------------------------------------\n")
    
    return score

# %%
# Running models: Logistic Regression & K-Neighbor & Support Vector Machine

run_model(LogisticRegression(max_iter = 40000), df, False)
run_model(LogisticRegression(max_iter = 40000), df_norm, True)

run_model(KNeighborsClassifier(n_neighbors = 9), df, False)
run_model(KNeighborsClassifier(n_neighbors = 9), df_norm, True)

run_model(SVC(max_iter = 40000), df, False)
temp = run_model(SVC(max_iter = 40000), df_norm, True) # To not show the returned score for visual cleanliness
# Out:
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Not normalized
#
# - Accuracy score:  0.8641304347826086
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.85      0.86      0.86        86
#          1.0       0.88      0.87      0.87        98
#
#     accuracy                           0.86       184
#    macro avg       0.86      0.86      0.86       184
# weighted avg       0.86      0.86      0.86       184
#
# - Confusion Matrix:
#
# 	True Positive:  13 	True Negative:  74
# 	False Positive:  12 	False Negative:  13
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.7119565217391305
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.65      0.70      0.67        79
#          1.0       0.76      0.72      0.74       105
#
#     accuracy                           0.71       184
#    macro avg       0.71      0.71      0.71       184
# weighted avg       0.71      0.71      0.71       184
#
# - Confusion Matrix:
#
# 	True Positive:  29 	True Negative:  55
# 	False Positive:  24 	False Negative:  29
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Not normalized
#
# - Accuracy score:  0.717391304347826
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.64      0.68      0.66        74
#          1.0       0.77      0.75      0.76       110
#
#     accuracy                           0.72       184
#    macro avg       0.71      0.71      0.71       184
# weighted avg       0.72      0.72      0.72       184
#
# - Confusion Matrix:
#
# 	True Positive:  28 	True Negative:  50
# 	False Positive:  24 	False Negative:  28
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Normalized
#
# - Accuracy score:  0.7391304347826086
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.67      0.70      0.68        74
#          1.0       0.79      0.76      0.78       110
#
#     accuracy                           0.74       184
#    macro avg       0.73      0.73      0.73       184
# weighted avg       0.74      0.74      0.74       184
#
# - Confusion Matrix:
#
# 	True Positive:  26 	True Negative:  52
# 	False Positive:  22 	False Negative:  26
#
# -------------------------------------------------------
#
# - Model:  SVC(max_iter=40000)
#
# - Data: Not normalized
#
# - Accuracy score:  0.7065217391304348
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.67      0.72      0.70        86
#          1.0       0.74      0.69      0.72        98
#
#     accuracy                           0.71       184
#    macro avg       0.71      0.71      0.71       184
# weighted avg       0.71      0.71      0.71       184
#
# - Confusion Matrix:
#
# 	True Positive:  30 	True Negative:  62
# 	False Positive:  24 	False Negative:  30
#
# -------------------------------------------------------
#
# - Model:  SVC(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.7336956521739131
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.67      0.76      0.71        79
#          1.0       0.80      0.71      0.75       105
#
#     accuracy                           0.73       184
#    macro avg       0.73      0.74      0.73       184
# weighted avg       0.74      0.73      0.74       184
#
# - Confusion Matrix:
#
# 	True Positive:  30 	True Negative:  60
# 	False Positive:  19 	False Negative:  30
#
# -------------------------------------------------------

# %%
# Function to calculate average accuracy score

def avg_accuracy (model, data, norm, iteration):
    
    score = 0
    for i in range(iteration):
        score = score + run_model(model, data, norm)
    
    return score / iteration

def print_avg_accuracy (model, norm, iteration, score):
    print("- Model: ", model, "\n")
    
    if norm == True:
        print("- Data: Normalized", "\n")
    else:
        print("- Data: Not normalized", "\n")
    
    print("- Iterations: ", iteration, '\n')
    
    print("- Average accuracy score: ", score)
    
    print("\n-------------------------------------------------------\n")

lr_unnorm_score = avg_accuracy(LogisticRegression(max_iter = 40000), df, False, 20)
lr_norm_score = avg_accuracy(LogisticRegression(max_iter = 40000), df, True, 20)
knc_unnorm_score = avg_accuracy(KNeighborsClassifier(n_neighbors = 9), df, False, 20)
knc_norm_score = avg_accuracy(KNeighborsClassifier(n_neighbors = 9), df, True, 20)
svc_unnorm_score = avg_accuracy(SVC(max_iter = 40000), df, False, 20)
svc_norm_score = avg_accuracy(SVC(max_iter = 40000), df, True, 20)
# Out:
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Not normalized
#
# - Accuracy score:  0.842391304347826
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.84      0.78      0.81        78
#          1.0       0.85      0.89      0.87       106
#
#     accuracy                           0.84       184
#    macro avg       0.84      0.83      0.84       184
# weighted avg       0.84      0.84      0.84       184
#
# - Confusion Matrix:
#
# 	True Positive:  12 	True Negative:  61
# 	False Positive:  17 	False Negative:  12
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Not normalized
#
# - Accuracy score:  0.8586956521739131
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.88      0.80      0.84        85
#          1.0       0.84      0.91      0.87        99
#
#     accuracy                           0.86       184
#    macro avg       0.86      0.85      0.86       184
# weighted avg       0.86      0.86      0.86       184
#
# - Confusion Matrix:
#
# 	True Positive:  9 	True Negative:  68
# 	False Positive:  17 	False Negative:  9
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Not normalized
#
# - Accuracy score:  0.8206521739130435
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.81      0.76      0.78        79
#          1.0       0.83      0.87      0.85       105
#
#     accuracy                           0.82       184
#    macro avg       0.82      0.81      0.82       184
# weighted avg       0.82      0.82      0.82       184
#
# - Confusion Matrix:
#
# 	True Positive:  14 	True Negative:  60
# 	False Positive:  19 	False Negative:  14
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Not normalized
#
# - Accuracy score:  0.8369565217391305
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.86      0.76      0.81        84
#          1.0       0.82      0.90      0.86       100
#
#     accuracy                           0.84       184
#    macro avg       0.84      0.83      0.83       184
# weighted avg       0.84      0.84      0.84       184
#
# - Confusion Matrix:
#
# 	True Positive:  10 	True Negative:  64
# 	False Positive:  20 	False Negative:  10
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Not normalized
#
# - Accuracy score:  0.8695652173913043
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.84      0.86      0.85        78
#          1.0       0.89      0.88      0.89       106
#
#     accuracy                           0.87       184
#    macro avg       0.87      0.87      0.87       184
# weighted avg       0.87      0.87      0.87       184
#
# - Confusion Matrix:
#
# 	True Positive:  13 	True Negative:  67
# 	False Positive:  11 	False Negative:  13
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Not normalized
#
# - Accuracy score:  0.8369565217391305
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.86      0.80      0.83        91
#          1.0       0.82      0.87      0.84        93
#
#     accuracy                           0.84       184
#    macro avg       0.84      0.84      0.84       184
# weighted avg       0.84      0.84      0.84       184
#
# - Confusion Matrix:
#
# 	True Positive:  12 	True Negative:  73
# 	False Positive:  18 	False Negative:  12
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Not normalized
#
# - Accuracy score:  0.8260869565217391
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.80      0.82      0.81        82
#          1.0       0.85      0.83      0.84       102
#
#     accuracy                           0.83       184
#    macro avg       0.82      0.83      0.82       184
# weighted avg       0.83      0.83      0.83       184
#
# - Confusion Matrix:
#
# 	True Positive:  17 	True Negative:  67
# 	False Positive:  15 	False Negative:  17
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Not normalized
#
# - Accuracy score:  0.8586956521739131
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.85      0.85      0.85        88
#          1.0       0.86      0.86      0.86        96
#
#     accuracy                           0.86       184
#    macro avg       0.86      0.86      0.86       184
# weighted avg       0.86      0.86      0.86       184
#
# - Confusion Matrix:
#
# 	True Positive:  13 	True Negative:  75
# 	False Positive:  13 	False Negative:  13
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Not normalized
#
# - Accuracy score:  0.8478260869565217
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.82      0.82      0.82        79
#          1.0       0.87      0.87      0.87       105
#
#     accuracy                           0.85       184
#    macro avg       0.84      0.84      0.84       184
# weighted avg       0.85      0.85      0.85       184
#
# - Confusion Matrix:
#
# 	True Positive:  14 	True Negative:  65
# 	False Positive:  14 	False Negative:  14
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Not normalized
#
# - Accuracy score:  0.8206521739130435
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.84      0.80      0.82        94
#          1.0       0.80      0.84      0.82        90
#
#     accuracy                           0.82       184
#    macro avg       0.82      0.82      0.82       184
# weighted avg       0.82      0.82      0.82       184
#
# - Confusion Matrix:
#
# 	True Positive:  14 	True Negative:  75
# 	False Positive:  19 	False Negative:  14
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Not normalized
#
# - Accuracy score:  0.8369565217391305
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.83      0.79      0.81        82
#          1.0       0.84      0.87      0.86       102
#
#     accuracy                           0.84       184
#    macro avg       0.84      0.83      0.83       184
# weighted avg       0.84      0.84      0.84       184
#
# - Confusion Matrix:
#
# 	True Positive:  13 	True Negative:  65
# 	False Positive:  17 	False Negative:  13
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Not normalized
#
# - Accuracy score:  0.8260869565217391
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.79      0.83      0.81        82
#          1.0       0.86      0.82      0.84       102
#
#     accuracy                           0.83       184
#    macro avg       0.82      0.83      0.82       184
# weighted avg       0.83      0.83      0.83       184
#
# - Confusion Matrix:
#
# 	True Positive:  18 	True Negative:  68
# 	False Positive:  14 	False Negative:  18
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Not normalized
#
# - Accuracy score:  0.8369565217391305
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.84      0.80      0.81        83
#          1.0       0.84      0.87      0.85       101
#
#     accuracy                           0.84       184
#    macro avg       0.84      0.83      0.83       184
# weighted avg       0.84      0.84      0.84       184
#
# - Confusion Matrix:
#
# 	True Positive:  13 	True Negative:  66
# 	False Positive:  17 	False Negative:  13
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Not normalized
#
# - Accuracy score:  0.8586956521739131
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.84      0.84      0.84        79
#          1.0       0.88      0.88      0.88       105
#
#     accuracy                           0.86       184
#    macro avg       0.86      0.86      0.86       184
# weighted avg       0.86      0.86      0.86       184
#
# - Confusion Matrix:
#
# 	True Positive:  13 	True Negative:  66
# 	False Positive:  13 	False Negative:  13
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Not normalized
# - Accuracy score:  0.8858695652173914
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.89      0.86      0.88        86
#          1.0       0.88      0.91      0.89        98
#
#     accuracy                           0.89       184
#    macro avg       0.89      0.88      0.89       184
# weighted avg       0.89      0.89      0.89       184
#
# - Confusion Matrix:
#
# 	True Positive:  9 	True Negative:  74
# 	False Positive:  12 	False Negative:  9
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Not normalized
#
# - Accuracy score:  0.8641304347826086
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.88      0.83      0.85        86
#          1.0       0.85      0.90      0.88        98
#
#     accuracy                           0.86       184
#    macro avg       0.87      0.86      0.86       184
# weighted avg       0.86      0.86      0.86       184
#
# - Confusion Matrix:
#
# 	True Positive:  10 	True Negative:  71
# 	False Positive:  15 	False Negative:  10
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Not normalized
#
# - Accuracy score:  0.7989130434782609
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.82      0.72      0.77        85
#          1.0       0.78      0.87      0.82        99
#
#     accuracy                           0.80       184
#    macro avg       0.80      0.79      0.80       184
# weighted avg       0.80      0.80      0.80       184
#
# - Confusion Matrix:
#
# 	True Positive:  13 	True Negative:  61
# 	False Positive:  24 	False Negative:  13
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Not normalized
#
# - Accuracy score:  0.7717391304347826
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.78      0.69      0.73        83
#          1.0       0.77      0.84      0.80       101
#
#     accuracy                           0.77       184
#    macro avg       0.77      0.76      0.77       184
# weighted avg       0.77      0.77      0.77       184
#
# - Confusion Matrix:
#
# 	True Positive:  16 	True Negative:  57
# 	False Positive:  26 	False Negative:  16
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Not normalized
#
# - Accuracy score:  0.8641304347826086
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.88      0.80      0.83        79
#          1.0       0.86      0.91      0.88       105
#
#     accuracy                           0.86       184
#    macro avg       0.87      0.86      0.86       184
# weighted avg       0.86      0.86      0.86       184
#
# - Confusion Matrix:
#
# 	True Positive:  9 	True Negative:  63
# 	False Positive:  16 	False Negative:  9
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Not normalized
#
# - Accuracy score:  0.8478260869565217
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.85      0.81      0.83        85
#          1.0       0.84      0.88      0.86        99
#
#     accuracy                           0.85       184
#    macro avg       0.85      0.85      0.85       184
# weighted avg       0.85      0.85      0.85       184
#
# - Confusion Matrix:
#
# 	True Positive:  12 	True Negative:  69
# 	False Positive:  16 	False Negative:  12
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.8478260869565217
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.88      0.78      0.82        85
#          1.0       0.83      0.91      0.87        99
#
#     accuracy                           0.85       184
#    macro avg       0.85      0.84      0.85       184
# weighted avg       0.85      0.85      0.85       184
#
# - Confusion Matrix:
#
# 	True Positive:  9 	True Negative:  66
# 	False Positive:  19 	False Negative:  9
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.8913043478260869
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.87      0.89      0.88        85
#          1.0       0.91      0.89      0.90        99
#
#     accuracy                           0.89       184
#    macro avg       0.89      0.89      0.89       184
# weighted avg       0.89      0.89      0.89       184
#
# - Confusion Matrix:
#
# 	True Positive:  11 	True Negative:  76
# 	False Positive:  9 	False Negative:  11
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.8641304347826086
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.86      0.83      0.85        83
#          1.0       0.87      0.89      0.88       101
#
#     accuracy                           0.86       184
#    macro avg       0.86      0.86      0.86       184
# weighted avg       0.86      0.86      0.86       184
#
# - Confusion Matrix:
#
# 	True Positive:  11 	True Negative:  69
# 	False Positive:  14 	False Negative:  11
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.8586956521739131
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.82      0.86      0.84        81
#          1.0       0.89      0.85      0.87       103
#
#     accuracy                           0.86       184
#    macro avg       0.86      0.86      0.86       184
# weighted avg       0.86      0.86      0.86       184
#
# - Confusion Matrix:
#
# 	True Positive:  15 	True Negative:  70
# 	False Positive:  11 	False Negative:  15
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.875
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.88      0.85      0.86        84
#          1.0       0.87      0.90      0.89       100
#
#     accuracy                           0.88       184
#    macro avg       0.88      0.87      0.87       184
# weighted avg       0.88      0.88      0.87       184
#
# - Confusion Matrix:
#
# 	True Positive:  10 	True Negative:  71
# 	False Positive:  13 	False Negative:  10
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.8260869565217391
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.84      0.78      0.81        86
#          1.0       0.82      0.87      0.84        98
#
#     accuracy                           0.83       184
#    macro avg       0.83      0.82      0.82       184
# weighted avg       0.83      0.83      0.83       184
#
# - Confusion Matrix:
#
# 	True Positive:  13 	True Negative:  67
# 	False Positive:  19 	False Negative:  13
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.8152173913043478
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.78      0.80      0.79        80
#          1.0       0.84      0.83      0.83       104
#
#     accuracy                           0.82       184
#    macro avg       0.81      0.81      0.81       184
# weighted avg       0.82      0.82      0.82       184
#
# - Confusion Matrix:
#
# 	True Positive:  18 	True Negative:  64
# 	False Positive:  16 	False Negative:  18
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.875
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.88      0.85      0.87        88
#          1.0       0.87      0.90      0.88        96
#
#     accuracy                           0.88       184
#    macro avg       0.88      0.87      0.87       184
# weighted avg       0.88      0.88      0.87       184
#
# - Confusion Matrix:
#
# 	True Positive:  10 	True Negative:  75
# 	False Positive:  13 	False Negative:  10
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Normalized
# - Accuracy score:  0.8532608695652174
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.81      0.85      0.83        78
#          1.0       0.88      0.86      0.87       106
#
#     accuracy                           0.85       184
#    macro avg       0.85      0.85      0.85       184
# weighted avg       0.85      0.85      0.85       184
#
# - Confusion Matrix:
#
# 	True Positive:  15 	True Negative:  66
# 	False Positive:  12 	False Negative:  15
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.8532608695652174
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.87      0.84      0.85        92
#          1.0       0.84      0.87      0.86        92
#
#     accuracy                           0.85       184
#    macro avg       0.85      0.85      0.85       184
# weighted avg       0.85      0.85      0.85       184
#
# - Confusion Matrix:
#
# 	True Positive:  12 	True Negative:  77
# 	False Positive:  15 	False Negative:  12
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.8315217391304348
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.85      0.80      0.82        90
#          1.0       0.82      0.86      0.84        94
#
#     accuracy                           0.83       184
#    macro avg       0.83      0.83      0.83       184
# weighted avg       0.83      0.83      0.83       184
#
# - Confusion Matrix:
#
# 	True Positive:  13 	True Negative:  72
# 	False Positive:  18 	False Negative:  13
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.8913043478260869
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.90      0.88      0.89        93
#          1.0       0.88      0.90      0.89        91
#
#     accuracy                           0.89       184
#    macro avg       0.89      0.89      0.89       184
# weighted avg       0.89      0.89      0.89       184
#
# - Confusion Matrix:
#
# 	True Positive:  9 	True Negative:  82
# 	False Positive:  11 	False Negative:  9
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.8641304347826086
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.92      0.78      0.84        87
#          1.0       0.83      0.94      0.88        97
#
#     accuracy                           0.86       184
#    macro avg       0.87      0.86      0.86       184
# weighted avg       0.87      0.86      0.86       184
#
# - Confusion Matrix:
#
# 	True Positive:  6 	True Negative:  68
# 	False Positive:  19 	False Negative:  6
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.842391304347826
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.85      0.82      0.83        89
#          1.0       0.84      0.86      0.85        95
#
#     accuracy                           0.84       184
#    macro avg       0.84      0.84      0.84       184
# weighted avg       0.84      0.84      0.84       184
#
# - Confusion Matrix:
#
# 	True Positive:  13 	True Negative:  73
# 	False Positive:  16 	False Negative:  13
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.8532608695652174
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.84      0.81      0.83        79
#          1.0       0.86      0.89      0.87       105
#
#     accuracy                           0.85       184
#    macro avg       0.85      0.85      0.85       184
# weighted avg       0.85      0.85      0.85       184
#
# - Confusion Matrix:
#
# 	True Positive:  12 	True Negative:  64
# 	False Positive:  15 	False Negative:  12
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.8478260869565217
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.84      0.82      0.83        84
#          1.0       0.85      0.87      0.86       100
#
#     accuracy                           0.85       184
#    macro avg       0.85      0.85      0.85       184
# weighted avg       0.85      0.85      0.85       184
#
# - Confusion Matrix:
#
# 	True Positive:  13 	True Negative:  69
# 	False Positive:  15 	False Negative:  13
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.8315217391304348
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.76      0.81      0.79        70
#          1.0       0.88      0.84      0.86       114
#
#     accuracy                           0.83       184
#    macro avg       0.82      0.83      0.82       184
# weighted avg       0.83      0.83      0.83       184
#
# - Confusion Matrix:
#
# 	True Positive:  18 	True Negative:  57
# 	False Positive:  13 	False Negative:  18
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.8532608695652174
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.84      0.83      0.84        83
#          1.0       0.86      0.87      0.87       101
#
#     accuracy                           0.85       184
#    macro avg       0.85      0.85      0.85       184
# weighted avg       0.85      0.85      0.85       184
#
# - Confusion Matrix:
#
# 	True Positive:  13 	True Negative:  69
# 	False Positive:  14 	False Negative:  13
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.8315217391304348
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.80      0.77      0.79        74
#          1.0       0.85      0.87      0.86       110
#
#     accuracy                           0.83       184
#    macro avg       0.83      0.82      0.82       184
# weighted avg       0.83      0.83      0.83       184
#
# - Confusion Matrix:
#
# 	True Positive:  14 	True Negative:  57
# 	False Positive:  17 	False Negative:  14
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.8369565217391305
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.82      0.77      0.79        75
#          1.0       0.85      0.88      0.86       109
#
#     accuracy                           0.84       184
#    macro avg       0.83      0.83      0.83       184
# weighted avg       0.84      0.84      0.84       184
#
# - Confusion Matrix:
#
# 	True Positive:  13 	True Negative:  58
# 	False Positive:  17 	False Negative:  13
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Not normalized
#
# - Accuracy score:  0.7010869565217391
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.64      0.60      0.62        75
#          1.0       0.74      0.77      0.75       109
#
#     accuracy                           0.70       184
#    macro avg       0.69      0.69      0.69       184
# weighted avg       0.70      0.70      0.70       184
#
# - Confusion Matrix:
#
# 	True Positive:  25 	True Negative:  45
# 	False Positive:  30 	False Negative:  25
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Not normalized
#
# - Accuracy score:  0.7391304347826086
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.66      0.68      0.67        71
#          1.0       0.79      0.78      0.79       113
#
#     accuracy                           0.74       184
#    macro avg       0.73      0.73      0.73       184
# weighted avg       0.74      0.74      0.74       184
#
# - Confusion Matrix:
#
# 	True Positive:  25 	True Negative:  48
# 	False Positive:  23 	False Negative:  25
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Not normalized
#
# - Accuracy score:  0.6956521739130435
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.62      0.64      0.63        75
#          1.0       0.75      0.73      0.74       109
#
#     accuracy                           0.70       184
#    macro avg       0.69      0.69      0.69       184
# weighted avg       0.70      0.70      0.70       184
#
# - Confusion Matrix:
#
# 	True Positive:  29 	True Negative:  48
# 	False Positive:  27 	False Negative:  29
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Not normalized
#
# - Accuracy score:  0.717391304347826
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.69      0.69      0.69        84
#          1.0       0.74      0.74      0.74       100
#
#     accuracy                           0.72       184
#    macro avg       0.72      0.72      0.72       184
# weighted avg       0.72      0.72      0.72       184
#
# - Confusion Matrix:
#
# 	True Positive:  26 	True Negative:  58
# 	False Positive:  26 	False Negative:  26
#
# -------------------------------------------------------
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Not normalized
#
# - Accuracy score:  0.7663043478260869
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.76      0.74      0.75        87
#          1.0       0.77      0.79      0.78        97
#
#     accuracy                           0.77       184
#    macro avg       0.77      0.76      0.77       184
# weighted avg       0.77      0.77      0.77       184
#
# - Confusion Matrix:
#
# 	True Positive:  20 	True Negative:  64
# 	False Positive:  23 	False Negative:  20
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Not normalized
#
# - Accuracy score:  0.6358695652173914
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.55      0.60      0.57        75
#          1.0       0.71      0.66      0.68       109
#
#     accuracy                           0.64       184
#    macro avg       0.63      0.63      0.63       184
# weighted avg       0.64      0.64      0.64       184
#
# - Confusion Matrix:
#
# 	True Positive:  37 	True Negative:  45
# 	False Positive:  30 	False Negative:  37
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Not normalized
#
# - Accuracy score:  0.6902173913043478
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.64      0.63      0.64        79
#          1.0       0.73      0.73      0.73       105
#
#     accuracy                           0.69       184
#    macro avg       0.68      0.68      0.68       184
# weighted avg       0.69      0.69      0.69       184
#
# - Confusion Matrix:
#
# 	True Positive:  28 	True Negative:  50
# 	False Positive:  29 	False Negative:  28
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Not normalized
#
# - Accuracy score:  0.7010869565217391
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.71      0.64      0.67        88
#          1.0       0.70      0.76      0.73        96
#
#     accuracy                           0.70       184
#    macro avg       0.70      0.70      0.70       184
# weighted avg       0.70      0.70      0.70       184
#
# - Confusion Matrix:
#
# 	True Positive:  23 	True Negative:  56
# 	False Positive:  32 	False Negative:  23
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Not normalized
#
# - Accuracy score:  0.7119565217391305
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.68      0.63      0.65        79
#          1.0       0.74      0.77      0.75       105
#
#     accuracy                           0.71       184
#    macro avg       0.71      0.70      0.70       184
# weighted avg       0.71      0.71      0.71       184
#
# - Confusion Matrix:
#
# 	True Positive:  24 	True Negative:  50
# 	False Positive:  29 	False Negative:  24
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Not normalized
#
# - Accuracy score:  0.7010869565217391
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.70      0.65      0.67        88
#          1.0       0.70      0.75      0.72        96
#
#     accuracy                           0.70       184
#    macro avg       0.70      0.70      0.70       184
# weighted avg       0.70      0.70      0.70       184
#
# - Confusion Matrix:
#
# 	True Positive:  24 	True Negative:  57
# 	False Positive:  31 	False Negative:  24
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Not normalized
#
# - Accuracy score:  0.6847826086956522
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.68      0.65      0.67        89
#          1.0       0.69      0.72      0.70        95
#
#     accuracy                           0.68       184
#    macro avg       0.68      0.68      0.68       184
# weighted avg       0.68      0.68      0.68       184
#
# - Confusion Matrix:
#
# 	True Positive:  27 	True Negative:  58
# 	False Positive:  31 	False Negative:  27
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Not normalized
#
# - Accuracy score:  0.7065217391304348
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.65      0.65      0.65        77
#          1.0       0.75      0.75      0.75       107
#
#     accuracy                           0.71       184
#    macro avg       0.70      0.70      0.70       184
# weighted avg       0.71      0.71      0.71       184
#
# - Confusion Matrix:
#
# 	True Positive:  27 	True Negative:  50
# 	False Positive:  27 	False Negative:  27
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Not normalized
#
# - Accuracy score:  0.7554347826086957
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.76      0.66      0.71        82
#          1.0       0.75      0.83      0.79       102
#
#     accuracy                           0.76       184
#    macro avg       0.76      0.75      0.75       184
# weighted avg       0.76      0.76      0.75       184
#
# - Confusion Matrix:
#
# 	True Positive:  17 	True Negative:  54
# 	False Positive:  28 	False Negative:  17
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Not normalized
#
# - Accuracy score:  0.6847826086956522
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.60      0.63      0.61        73
#          1.0       0.75      0.72      0.73       111
#
#     accuracy                           0.68       184
#    macro avg       0.67      0.68      0.67       184
# weighted avg       0.69      0.68      0.69       184
#
# - Confusion Matrix:
#
# 	True Positive:  31 	True Negative:  46
# 	False Positive:  27 	False Negative:  31
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Not normalized
#
# - Accuracy score:  0.7228260869565217
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.72      0.68      0.70        87
#          1.0       0.73      0.76      0.74        97
#
#     accuracy                           0.72       184
#    macro avg       0.72      0.72      0.72       184
# weighted avg       0.72      0.72      0.72       184
#
# - Confusion Matrix:
#
# 	True Positive:  23 	True Negative:  59
# 	False Positive:  28 	False Negative:  23
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Not normalized
#
# - Accuracy score:  0.6847826086956522
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.61      0.59      0.60        73
#          1.0       0.73      0.75      0.74       111
#
#     accuracy                           0.68       184
#    macro avg       0.67      0.67      0.67       184
# weighted avg       0.68      0.68      0.68       184
#
# - Confusion Matrix:
#
# 	True Positive:  28 	True Negative:  43
# 	False Positive:  30 	False Negative:  28
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Not normalized
#
# - Accuracy score:  0.7282608695652174
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.76      0.69      0.72        94
#          1.0       0.70      0.77      0.73        90
#
#     accuracy                           0.73       184
#    macro avg       0.73      0.73      0.73       184
# weighted avg       0.73      0.73      0.73       184
#
# - Confusion Matrix:
#
# 	True Positive:  21 	True Negative:  65
# 	False Positive:  29 	False Negative:  21
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Not normalized
#
# - Accuracy score:  0.7010869565217391
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.73      0.60      0.66        88
#          1.0       0.68      0.79      0.73        96
#
#     accuracy                           0.70       184
#    macro avg       0.71      0.70      0.70       184
# weighted avg       0.70      0.70      0.70       184
#
# - Confusion Matrix:
#
# 	True Positive:  20 	True Negative:  53
# 	False Positive:  35 	False Negative:  20
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Not normalized
#
# - Accuracy score:  0.6739130434782609
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.67      0.62      0.64        87
#          1.0       0.68      0.72      0.70        97
#
#     accuracy                           0.67       184
#    macro avg       0.67      0.67      0.67       184
# weighted avg       0.67      0.67      0.67       184
#
# - Confusion Matrix:
#
# 	True Positive:  27 	True Negative:  54
# 	False Positive:  33 	False Negative:  27
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Not normalized
#
# - Accuracy score:  0.7065217391304348
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.72      0.62      0.67        87
#          1.0       0.70      0.78      0.74        97
#
#     accuracy                           0.71       184
#    macro avg       0.71      0.70      0.70       184
# weighted avg       0.71      0.71      0.70       184
#
# - Confusion Matrix:
#
# 	True Positive:  21 	True Negative:  54
# 	False Positive:  33 	False Negative:  21
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Normalized
#
# - Accuracy score:  0.657608695652174
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.60      0.62      0.61        80
#          1.0       0.70      0.68      0.69       104
#
#     accuracy                           0.66       184
#    macro avg       0.65      0.65      0.65       184
# weighted avg       0.66      0.66      0.66       184
# - Confusion Matrix:
#
# 	True Positive:  33 	True Negative:  50
# 	False Positive:  30 	False Negative:  33
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Normalized
#
# - Accuracy score:  0.7119565217391305
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.70      0.70      0.70        89
#          1.0       0.72      0.73      0.72        95
#
#     accuracy                           0.71       184
#    macro avg       0.71      0.71      0.71       184
# weighted avg       0.71      0.71      0.71       184
#
# - Confusion Matrix:
#
# 	True Positive:  26 	True Negative:  62
# 	False Positive:  27 	False Negative:  26
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Normalized
#
# - Accuracy score:  0.717391304347826
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.73      0.65      0.69        88
#          1.0       0.71      0.78      0.74        96
#
#     accuracy                           0.72       184
#    macro avg       0.72      0.71      0.71       184
# weighted avg       0.72      0.72      0.72       184
#
# - Confusion Matrix:
#
# 	True Positive:  21 	True Negative:  57
# 	False Positive:  31 	False Negative:  21
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Normalized
#
# - Accuracy score:  0.7445652173913043
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.76      0.66      0.71        86
#          1.0       0.73      0.82      0.77        98
#
#     accuracy                           0.74       184
#    macro avg       0.75      0.74      0.74       184
# weighted avg       0.75      0.74      0.74       184
#
# - Confusion Matrix:
#
# 	True Positive:  18 	True Negative:  57
# 	False Positive:  29 	False Negative:  18
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Normalized
#
# - Accuracy score:  0.6739130434782609
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.63      0.69      0.66        83
#          1.0       0.72      0.66      0.69       101
#
#     accuracy                           0.67       184
#    macro avg       0.67      0.68      0.67       184
# weighted avg       0.68      0.67      0.67       184
#
# - Confusion Matrix:
#
# 	True Positive:  34 	True Negative:  57
# 	False Positive:  26 	False Negative:  34
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Normalized
#
# - Accuracy score:  0.6847826086956522
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.65      0.63      0.64        82
#          1.0       0.71      0.73      0.72       102
#
#     accuracy                           0.68       184
#    macro avg       0.68      0.68      0.68       184
# weighted avg       0.68      0.68      0.68       184
#
# - Confusion Matrix:
#
# 	True Positive:  28 	True Negative:  52
# 	False Positive:  30 	False Negative:  28
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Normalized
#
# - Accuracy score:  0.6739130434782609
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.66      0.60      0.63        85
#          1.0       0.68      0.74      0.71        99
#
#     accuracy                           0.67       184
#    macro avg       0.67      0.67      0.67       184
# weighted avg       0.67      0.67      0.67       184
#
# - Confusion Matrix:
#
# 	True Positive:  26 	True Negative:  51
# 	False Positive:  34 	False Negative:  26
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Normalized
#
# - Accuracy score:  0.7554347826086957
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.66      0.72      0.69        69
#          1.0       0.82      0.77      0.80       115
#
#     accuracy                           0.76       184
#    macro avg       0.74      0.75      0.74       184
# weighted avg       0.76      0.76      0.76       184
#
# - Confusion Matrix:
#
# 	True Positive:  26 	True Negative:  50
# 	False Positive:  19 	False Negative:  26
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Normalized
#
# - Accuracy score:  0.7065217391304348
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.68      0.61      0.64        79
#          1.0       0.73      0.78      0.75       105
#
#     accuracy                           0.71       184
#    macro avg       0.70      0.69      0.70       184
# weighted avg       0.70      0.71      0.70       184
#
# - Confusion Matrix:
#
# 	True Positive:  23 	True Negative:  48
# 	False Positive:  31 	False Negative:  23
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Normalized
#
# - Accuracy score:  0.7228260869565217
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.72      0.67      0.69        86
#          1.0       0.73      0.77      0.75        98
#
#     accuracy                           0.72       184
#    macro avg       0.72      0.72      0.72       184
# weighted avg       0.72      0.72      0.72       184
#
# - Confusion Matrix:
#
# 	True Positive:  23 	True Negative:  58
# 	False Positive:  28 	False Negative:  23
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Normalized
#
# - Accuracy score:  0.7119565217391305
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.76      0.60      0.67        91
#          1.0       0.68      0.82      0.74        93
#
#     accuracy                           0.71       184
#    macro avg       0.72      0.71      0.71       184
# weighted avg       0.72      0.71      0.71       184
#
# - Confusion Matrix:
#
# 	True Positive:  17 	True Negative:  55
# 	False Positive:  36 	False Negative:  17
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Normalized
#
# - Accuracy score:  0.7119565217391305
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.69      0.67      0.68        84
#          1.0       0.73      0.75      0.74       100
#
#     accuracy                           0.71       184
#    macro avg       0.71      0.71      0.71       184
# weighted avg       0.71      0.71      0.71       184
#
# - Confusion Matrix:
#
# 	True Positive:  25 	True Negative:  56
# 	False Positive:  28 	False Negative:  25
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Normalized
#
# - Accuracy score:  0.717391304347826
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.70      0.63      0.67        82
#          1.0       0.73      0.78      0.75       102
#
#     accuracy                           0.72       184
#    macro avg       0.71      0.71      0.71       184
# weighted avg       0.72      0.72      0.72       184
#
# - Confusion Matrix:
#
# 	True Positive:  22 	True Negative:  52
# 	False Positive:  30 	False Negative:  22
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Normalized
#
# - Accuracy score:  0.717391304347826
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.65      0.71      0.68        77
#          1.0       0.78      0.72      0.75       107
#
#     accuracy                           0.72       184
#    macro avg       0.71      0.72      0.71       184
# weighted avg       0.72      0.72      0.72       184
#
# - Confusion Matrix:
#
# 	True Positive:  30 	True Negative:  55
# 	False Positive:  22 	False Negative:  30
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Normalized
#
# - Accuracy score:  0.7119565217391305
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.59      0.69      0.64        68
#          1.0       0.80      0.72      0.76       116
#
#     accuracy                           0.71       184
#    macro avg       0.70      0.71      0.70       184
# weighted avg       0.72      0.71      0.72       184
#
# - Confusion Matrix:
#
# 	True Positive:  32 	True Negative:  47
# 	False Positive:  21 	False Negative:  32
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Normalized
#
# - Accuracy score:  0.5978260869565217
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.68      0.51      0.58       101
#          1.0       0.54      0.70      0.61        83
#
#     accuracy                           0.60       184
#    macro avg       0.61      0.61      0.60       184
# weighted avg       0.62      0.60      0.60       184
#
# - Confusion Matrix:
#
# 	True Positive:  25 	True Negative:  52
# 	False Positive:  49 	False Negative:  25
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Normalized
#
# - Accuracy score:  0.6467391304347826
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.59      0.57      0.58        79
#          1.0       0.69      0.70      0.69       105
#
#     accuracy                           0.65       184
# ...
#
# 	True Positive:  25 	True Negative:  50
# 	False Positive:  24 	False Negative:  25
#
# -------------------------------------------------------
#
# - Model:  SVC(max_iter=40000)
#
# - Data: Not normalized
#
# - Accuracy score:  0.6847826086956522
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.61      0.63      0.62        75
#          1.0       0.74      0.72      0.73       109
#
#     accuracy                           0.68       184
#    macro avg       0.67      0.68      0.67       184
# weighted avg       0.69      0.68      0.69       184
#
# - Confusion Matrix:
#
# 	True Positive:  30 	True Negative:  47
# 	False Positive:  28 	False Negative:  30
#
# -------------------------------------------------------
#
# - Model:  SVC(max_iter=40000)
#
# - Data: Not normalized
#
# - Accuracy score:  0.7771739130434783
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.80      0.72      0.76        90
#          1.0       0.76      0.83      0.79        94
#
#     accuracy                           0.78       184
#    macro avg       0.78      0.78      0.78       184
# weighted avg       0.78      0.78      0.78       184
#
# - Confusion Matrix:
#
# 	True Positive:  16 	True Negative:  65
# 	False Positive:  25 	False Negative:  16
#
# -------------------------------------------------------
#
# - Model:  SVC(max_iter=40000)
#
# - Data: Not normalized
#
# - Accuracy score:  0.7717391304347826
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.71      0.78      0.75        79
#          1.0       0.82      0.76      0.79       105
#
#     accuracy                           0.77       184
#    macro avg       0.77      0.77      0.77       184
# weighted avg       0.78      0.77      0.77       184
#
# - Confusion Matrix:
#
# 	True Positive:  25 	True Negative:  62
# 	False Positive:  17 	False Negative:  25
#
# -------------------------------------------------------
#
# - Model:  SVC(max_iter=40000)
#
# - Data: Not normalized
#
# - Accuracy score:  0.7771739130434783
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.76      0.71      0.74        80
#          1.0       0.79      0.83      0.81       104
#
#     accuracy                           0.78       184
#    macro avg       0.77      0.77      0.77       184
# weighted avg       0.78      0.78      0.78       184
#
# - Confusion Matrix:
#
# 	True Positive:  18 	True Negative:  57
# 	False Positive:  23 	False Negative:  18
#
# -------------------------------------------------------
#
# - Model:  SVC(max_iter=40000)
#
# - Data: Not normalized
#
# - Accuracy score:  0.7065217391304348
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.73      0.62      0.67        89
#          1.0       0.69      0.79      0.74        95
#
#     accuracy                           0.71       184
#    macro avg       0.71      0.70      0.70       184
# weighted avg       0.71      0.71      0.70       184
#
# - Confusion Matrix:
#
# 	True Positive:  20 	True Negative:  55
# 	False Positive:  34 	False Negative:  20
#
# -------------------------------------------------------
#
# - Model:  SVC(max_iter=40000)
#
# - Data: Not normalized
#
# - Accuracy score:  0.75
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.77      0.64      0.70        84
#          1.0       0.74      0.84      0.79       100
#
#     accuracy                           0.75       184
#    macro avg       0.75      0.74      0.74       184
# weighted avg       0.75      0.75      0.75       184
#
# - Confusion Matrix:
#
# 	True Positive:  16 	True Negative:  54
# 	False Positive:  30 	False Negative:  16
#
# -------------------------------------------------------
#
# - Model:  SVC(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.7554347826086957
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.72      0.69      0.71        78
#          1.0       0.78      0.80      0.79       106
#
#     accuracy                           0.76       184
#    macro avg       0.75      0.75      0.75       184
# weighted avg       0.75      0.76      0.75       184
#
# - Confusion Matrix:
#
# 	True Positive:  21 	True Negative:  54
# 	False Positive:  24 	False Negative:  21
#
# -------------------------------------------------------
#
# - Model:  SVC(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.7282608695652174
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.69      0.77      0.73        86
#          1.0       0.77      0.69      0.73        98
#
#     accuracy                           0.73       184
#    macro avg       0.73      0.73      0.73       184
# weighted avg       0.73      0.73      0.73       184
#
# - Confusion Matrix:
#
# 	True Positive:  30 	True Negative:  66
# 	False Positive:  20 	False Negative:  30
#
# -------------------------------------------------------
#
# - Model:  SVC(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.7010869565217391
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.70      0.66      0.68        89
#          1.0       0.70      0.74      0.72        95
#
#     accuracy                           0.70       184
#    macro avg       0.70      0.70      0.70       184
# weighted avg       0.70      0.70      0.70       184
#
# - Confusion Matrix:
#
# 	True Positive:  25 	True Negative:  59
# 	False Positive:  30 	False Negative:  25
#
# -------------------------------------------------------
#
# - Model:  SVC(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.7608695652173914
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.70      0.77      0.73        78
#          1.0       0.82      0.75      0.78       106
#
#     accuracy                           0.76       184
#    macro avg       0.76      0.76      0.76       184
# weighted avg       0.77      0.76      0.76       184
#
# - Confusion Matrix:
#
# 	True Positive:  26 	True Negative:  60
# 	False Positive:  18 	False Negative:  26
#
# -------------------------------------------------------
#
# - Model:  SVC(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.7065217391304348
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.70      0.66      0.68        86
#          1.0       0.72      0.74      0.73        98
#
#     accuracy                           0.71       184
#    macro avg       0.71      0.70      0.70       184
# weighted avg       0.71      0.71      0.71       184
#
# - Confusion Matrix:
#
# 	True Positive:  25 	True Negative:  57
# 	False Positive:  29 	False Negative:  25
#
# -------------------------------------------------------
#
# - Model:  SVC(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.7010869565217391
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.73      0.65      0.69        93
#          1.0       0.68      0.76      0.72        91
#
#     accuracy                           0.70       184
#    macro avg       0.70      0.70      0.70       184
# weighted avg       0.70      0.70      0.70       184
#
# - Confusion Matrix:
#
# 	True Positive:  22 	True Negative:  60
# 	False Positive:  33 	False Negative:  22
#
# -------------------------------------------------------
#
# - Model:  SVC(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.7391304347826086
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.67      0.68      0.68        73
#          1.0       0.79      0.77      0.78       111
#
#     accuracy                           0.74       184
#    macro avg       0.73      0.73      0.73       184
# weighted avg       0.74      0.74      0.74       184
#
# - Confusion Matrix:
#
# 	True Positive:  25 	True Negative:  50
# 	False Positive:  23 	False Negative:  25
#
# -------------------------------------------------------
#
# - Model:  SVC(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.7771739130434783
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.78      0.73      0.75        85
#          1.0       0.78      0.82      0.80        99
#
#     accuracy                           0.78       184
#    macro avg       0.78      0.77      0.77       184
# weighted avg       0.78      0.78      0.78       184
#
# - Confusion Matrix:
#
# 	True Positive:  18 	True Negative:  62
# 	False Positive:  23 	False Negative:  18
#
# -------------------------------------------------------
#
# - Model:  SVC(max_iter=40000)
#
# - Data: Normalized
# - Accuracy score:  0.7282608695652174
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.72      0.71      0.72        89
#          1.0       0.73      0.75      0.74        95
#
#     accuracy                           0.73       184
#    macro avg       0.73      0.73      0.73       184
# weighted avg       0.73      0.73      0.73       184
#
# - Confusion Matrix:
#
# 	True Positive:  24 	True Negative:  63
# 	False Positive:  26 	False Negative:  24
#
# -------------------------------------------------------
#
# - Model:  SVC(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.7445652173913043
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.72      0.71      0.71        82
#          1.0       0.77      0.77      0.77       102
#
#     accuracy                           0.74       184
#    macro avg       0.74      0.74      0.74       184
# weighted avg       0.74      0.74      0.74       184
#
# - Confusion Matrix:
#
# 	True Positive:  23 	True Negative:  58
# 	False Positive:  24 	False Negative:  23
#
# -------------------------------------------------------
#
# - Model:  SVC(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.717391304347826
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.65      0.73      0.69        79
#          1.0       0.78      0.70      0.74       105
#
#     accuracy                           0.72       184
#    macro avg       0.72      0.72      0.72       184
# weighted avg       0.72      0.72      0.72       184
#
# - Confusion Matrix:
#
# 	True Positive:  31 	True Negative:  58
# 	False Positive:  21 	False Negative:  31
#
# -------------------------------------------------------
#
# - Model:  SVC(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.717391304347826
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.65      0.69      0.67        77
#          1.0       0.77      0.74      0.75       107
#
#     accuracy                           0.72       184
#    macro avg       0.71      0.71      0.71       184
# weighted avg       0.72      0.72      0.72       184
#
# - Confusion Matrix:
#
# 	True Positive:  28 	True Negative:  53
# 	False Positive:  24 	False Negative:  28
#
# -------------------------------------------------------
#
# - Model:  SVC(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.6902173913043478
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.68      0.69      0.69        90
#          1.0       0.70      0.69      0.70        94
#
#     accuracy                           0.69       184
#    macro avg       0.69      0.69      0.69       184
# weighted avg       0.69      0.69      0.69       184
#
# - Confusion Matrix:
#
# 	True Positive:  29 	True Negative:  62
# 	False Positive:  28 	False Negative:  29
#
# -------------------------------------------------------
#
# - Model:  SVC(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.7608695652173914
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.69      0.76      0.72        76
#          1.0       0.82      0.76      0.79       108
#
#     accuracy                           0.76       184
#    macro avg       0.76      0.76      0.76       184
# weighted avg       0.77      0.76      0.76       184
#
# - Confusion Matrix:
#
# 	True Positive:  26 	True Negative:  58
# 	False Positive:  18 	False Negative:  26
#
# -------------------------------------------------------
#
# - Model:  SVC(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.7228260869565217
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.68      0.69      0.69        81
#          1.0       0.75      0.75      0.75       103
#
#     accuracy                           0.72       184
#    macro avg       0.72      0.72      0.72       184
# weighted avg       0.72      0.72      0.72       184
#
# - Confusion Matrix:
#
# 	True Positive:  26 	True Negative:  56
# 	False Positive:  25 	False Negative:  26
#
# -------------------------------------------------------
#
# - Model:  SVC(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.75
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.71      0.70      0.71        79
#          1.0       0.78      0.79      0.78       105
#
#     accuracy                           0.75       184
#    macro avg       0.74      0.74      0.74       184
# weighted avg       0.75      0.75      0.75       184
#
# - Confusion Matrix:
#
# 	True Positive:  22 	True Negative:  55
# 	False Positive:  24 	False Negative:  22
#
# -------------------------------------------------------
#
# - Model:  SVC(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.7336956521739131
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.70      0.71      0.71        83
#          1.0       0.76      0.75      0.76       101
#
#     accuracy                           0.73       184
#    macro avg       0.73      0.73      0.73       184
# weighted avg       0.73      0.73      0.73       184
#
# - Confusion Matrix:
#
# 	True Positive:  25 	True Negative:  59
# 	False Positive:  24 	False Negative:  25
#
# -------------------------------------------------------
#
# - Model:  SVC(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.7282608695652174
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.69      0.67      0.68        79
#          1.0       0.76      0.77      0.76       105
#
#     accuracy                           0.73       184
#    macro avg       0.72      0.72      0.72       184
# weighted avg       0.73      0.73      0.73       184
#
# - Confusion Matrix:
#
# 	True Positive:  24 	True Negative:  53
# 	False Positive:  26 	False Negative:  24
#
# -------------------------------------------------------
#
# - Model:  SVC(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.7065217391304348
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.66      0.73      0.69        84
#          1.0       0.75      0.69      0.72       100
#
#     accuracy                           0.71       184
#    macro avg       0.71      0.71      0.71       184
# weighted avg       0.71      0.71      0.71       184
#
# - Confusion Matrix:
#
# 	True Positive:  31 	True Negative:  61
# 	False Positive:  23 	False Negative:  31
#
# -------------------------------------------------------
#
# - Model:  SVC(max_iter=40000)
#
# - Data: Normalized
#
# - Accuracy score:  0.6630434782608695
#
# - Classification Report:
#
#                precision    recall  f1-score   support
#
#          0.0       0.65      0.59      0.62        86
#          1.0       0.67      0.72      0.70        98
#
#     accuracy                           0.66       184
#    macro avg       0.66      0.66      0.66       184
# weighted avg       0.66      0.66      0.66       184
#
# - Confusion Matrix:
#
# 	True Positive:  27 	True Negative:  51
# 	False Positive:  35 	False Negative:  27
#
# -------------------------------------------------------

# %%
print_avg_accuracy(LogisticRegression(max_iter = 40000), False, 20, lr_unnorm_score)
print_avg_accuracy(LogisticRegression(max_iter = 40000), True, 20, lr_norm_score)
print_avg_accuracy(KNeighborsClassifier(n_neighbors = 9), False, 20, knc_unnorm_score)
print_avg_accuracy(KNeighborsClassifier(n_neighbors = 9), True, 20, knc_norm_score)
print_avg_accuracy(SVC(max_iter = 40000), False, 20, svc_unnorm_score)
print_avg_accuracy(SVC(max_iter = 40000), True, 20, svc_norm_score)
# Out:
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Not normalized
#
# - Iterations:  20
#
# - Average accuracy score:  0.8404891304347828
#
# -------------------------------------------------------
#
# - Model:  LogisticRegression(max_iter=40000)
#
# - Data: Normalized
#
# - Iterations:  20
#
# - Average accuracy score:  0.8521739130434783
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Not normalized
#
# - Iterations:  20
#
# - Average accuracy score:  0.7054347826086957
#
# -------------------------------------------------------
#
# - Model:  KNeighborsClassifier(n_neighbors=9)
#
# - Data: Normalized
#
# - Iterations:  20
#
# - Average accuracy score:  0.7016304347826088
#
# -------------------------------------------------------
#
# - Model:  SVC(max_iter=40000)
#
# - Data: Not normalized
#
# - Iterations:  20
#
# - Average accuracy score:  0.7304347826086959
#
# -------------------------------------------------------
#
# - Model:  SVC(max_iter=40000)
#
# - Data: Normalized
#
# - Iterations:  20
#
# - Average accuracy score:  0.7266304347826087
#
# -------------------------------------------------------
